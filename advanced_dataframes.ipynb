# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from env import host, username, password
from pydataset import data

url = f'mysql+pymysql://{username}:{password}@{host}/employees'

# %%
pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url)
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10051  1953-07-28   Hidefumi      Caine      M  1992-10-15
# 1   10052  1961-02-26     Heping     Nitsch      M  1988-05-21
# 2   10053  1954-09-13     Sanjiv   Zschoche      F  1986-02-04
# 3   10054  1957-04-04     Mayumi  Schueller      M  1995-03-13
# 4   10055  1956-06-06     Georgy     Dredge      M  1992-04-27

# %%
#1.) Create a function named get_db_url. It should accept a username, hostname, password, and database name and 
#return a url connection string formatted like in the example at the start of this lesson.

def get_db_url(username,password,host,db_name):
    return f'mysql+pymysql://{username}:{password}@{host}/{db_name}'
url =  get_db_url(username,password,host, 'employees')

# %%
#2.) Use your function to obtain a connection to the employees database.
get_db_url(username,password,host, 'employees')
emp_url = get_db_url(username,password,host, 'employees')
pd.read_sql('select * from employees limit 5', emp_url)
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
#3a.) Intentionally make a typo in the database url. What kind of error message do you see? Operational Error
emp_url = get_db_url(username,password,host, 'elployees')
pd.read_sql('select * from employees limit 5', emp_url)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pymysql/connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     352         else:
# --> 353             self.connect()
#     354
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pymysql/connections.py in connect(self, sock)
#     632             self._get_server_information()
# --> 633             self._request_authentication()
#     634
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pymysql/connections.py in _request_authentication(self)
#     906         self.write_packet(data)
# --> 907         auth_packet = self._read_packet()
#     908
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pymysql/protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# OperationalError: (1044, "Access denied for user 'germain_1467'@'%' to database 'elployees'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-5-4d98998dea5d> in <module>
#       1 #3a.) Intentionally make a typo in the database url. What kind of error message do you see? Operational Error
#       2 emp_url = get_db_url(username,password,host, 'elployees')
# ----> 3 pd.read_sql('select * from employees limit 5', emp_url)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     519         )
#     520     else:
# --> 521         return pandas_sql.read_query(
#     522             sql,
#     523             index_col=index_col,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1306         args = _convert_params(sql, params)
#    1307
# -> 1308         result = self.execute(*args)
#    1309         columns = result.keys()
#    1310
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1174     def execute(self, *args, **kwargs):
#    1175         """Simple passthrough to SQLAlchemy connectable"""
# -> 1176         return self.connectable.execution_options().execute(*args, **kwargs)
#    1177
#    1178     def read_table(
#
# <string> in execute(self, statement, *multiparams, **params)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    3034
#    3035         """
# -> 3036         connection = self.connect(close_with_result=True)
#    3037         return connection.execute(statement, *multiparams, **params)
#    3038
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in connect(self, close_with_result)
#    3093         """
#    3094
# -> 3095         return self._connection_cls(self, close_with_result=close_with_result)
#    3096
#    3097     @util.deprecated(
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      89                 connection
#      90                 if connection is not None
# ---> 91                 else engine.raw_connection()
#      92             )
#      93
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    3172
#    3173         """
# -> 3174         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3175
#    3176
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3142         except dialect.dbapi.Error as e:
#    3143             if connection is None:
# -> 3144                 Connection._handle_dbapi_exception_noconnection(
#    3145                     e, dialect, self
#    3146                 )
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2001             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2002         elif should_wrap:
# -> 2003             util.raise_(
#    2004                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2005             )
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3139         dialect = self.dialect
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#    3143             if connection is None:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     299
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#     303     def _return_conn(self, record):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     753     def _checkout(cls, pool, threadconns=None, fairy=None):
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#     757             fairy._pool = pool
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     417     @classmethod
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#     421             dbapi_connection = rec.get_connection()
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     143             except:
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#     147             return self._do_get()
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     140         if self._inc_overflow():
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#     144                 with util.safe_reraise():
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     245         """Called by subclasses to create a new ConnectionRecord."""
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#     249     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     360         self.__pool = pool
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#     364
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     603         except Exception as e:
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#     607             if first_connect_check:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     597         try:
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#     601             self.connection = connection
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     557     def connect(self, *cargs, **cparams):
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#     561     def create_connect_args(self, url):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pymysql/connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pymysql/connections.py in connect(self, sock)
#     631
#     632             self._get_server_information()
# --> 633             self._request_authentication()
#     634
#     635             if self.sql_mode is not None:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pymysql/connections.py in _request_authentication(self)
#     905
#     906         self.write_packet(data)
# --> 907         auth_packet = self._read_packet()
#     908
#     909         # if authentication method isn't accepted the first byte
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pymysql/protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1044, "Access denied for user 'germain_1467'@'%' to database 'elployees'")
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
#3b.)  Intentionally make an error in your SQL query. What does the error message look like? programming error
emp_url = get_db_url(username,password,host, 'employees')
pd.read_sql('select all from employees limit 5', emp_url)

# %%
#4.) Read the employees and titles tables into two separate DataFrames.
titles_df = pd.read_sql('select * from titles', emp_url)
titles_df

# %%
employees_df = pd.read_sql('select * from employees', emp_url)
employees_df

# %%
#6.) Display the summary statistics for each DataFrame.
employees_df.describe()

# %%
#6.) Display the summary statistics for each DataFrame.
titles_df.describe()

# %%
#7.) How many unique titles are in the titles DataFrame?
emp_url = get_db_url(username,password,host, 'employees')
len(pd.read_sql('select distinct title from titles', emp_url))
#7 unique titles

# %%
#8.) What is the oldest date in the to_date column? 1985-03-01

pd.read_sql('select to_date from titles order by to_date asc limit 1', emp_url)

# %%
#9.) What is the most recent date in the to_date column? 2002-08-01
pd.read_sql('select to_date from titles where to_date < now() order by to_date desc limit 1', emp_url)

# %% [markdown]
# Exercise 2

# %%
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
print(users)

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles

# %%
##2. What is the result of using a right join on the DataFrames?

users.merge(roles, left_on='role_id', right_on='id', how='right', indicator=True)

# %%
##3. What is the result of using an outer join on the DataFrames?

users.merge(roles, left_on='role_id', right_on='id', how='outer', indicator=True)

# %%
##4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

noforeignkey_users = users.drop(columns='role_id')
noforeignkey_users

pd.merge(noforeignkey_users, roles, on='id')

# %%
mpg = data('mpg')
mpg

# %%
#6. Output and read the documentation for the mpg dataset.

mpg

# %%
#7. How many rows and columns are in the dataset?

mpg.info

# %%
#8. Check out your column names and perform any cleanup you may want on them.

mpg_df = mpg
mpg_df=mpg_df.rename(columns={'cty': 'city'})
mpg_df=mpg_df.rename(columns={'hwy': 'highway'})
mpg_df=mpg_df.rename(columns={'trans': 'transmission'})
mpg_df=mpg_df.rename(columns={'displ': 'displacement'})

mpg_df=mpg_df.rename(columns={'cty': 'city',
                               'hwy': 'highway',
                            'trans': 'transmission',
                            'displ': 'displacement'})

# %%
mpg_df

# %%
#9. Display the summary statistics for the dataset.

mpg.describe()

# %%
#10. How many different manufacturers are there?

len(set(mpg_df['manufacturer']))

# %%
# 11. How many different models are there?
len(set(mpg_df['model']))

# %%
## 12. Create a column named mileage_difference like you did in the DataFrames exercises; 
#this column should contain the difference between highway and city mileage for each car.

mpg = mpg_df.assign(mileage_difference = mpg_df.highway - mpg_df.city)
mpg.head()

# %%
#13. Create a column named average_mileage like you did in the DataFrames exercises; 
##this is the mean of the city and highway mileage.

mpg['average_mileage'] = (mpg_df.city + mpg_df.highway) / 2

mpg.head()

# %%
#14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

mpg['is_automatic'] = mpg_df.transmission.str.startswith('auto')
mpg

# %%
#15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?


mpg.groupby('manufacturer').average_mileage.mean().sort_values().nlargest(1, keep='all')
mpg.groupby('manufacturer').average_mileage.agg('mean').nlargest(1)

# %%
#16. Do automatic or manual cars have better miles per gallon?

mpg.groupby('is_automatic').average_mileage.mean()

# %%
##Exercises III
##Use your get_db_url function to help you explore the data from the chipotle database.

get_db_url(username,password,host, 'chipotle')
chip_url = get_db_url(username,password,host, 'chipotle')
orders_df = pd.read_sql('select * from orders', chip_url)

# %%
##2. What is the total price for each order?


orders_df
orders_df.item_price = orders_df.item_price.str.replace('$','').str.replace(',','').astype('float')
orders_df.groupby('order_id').item_price.sum()

orders_df
# Out:
# <ipython-input-7-54d5493615f8>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   orders_df.item_price = orders_df.item_price.str.replace('$','').str.replace(',','').astype('float')
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# 0                                                                                   nan
# 1                                                                          [Clementine]
# 2                                                                               [Apple]
# 3                                                                                   nan
# 4            [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# ...                                                                                 ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour Cream, Cheese, Lettuce, Guacamole]]
# 4618               [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese, Lettuce, Guacamole]]
# 4619         [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Guacamole, Lettuce]]
# 4620                                 [Fresh Tomato Salsa, [Fajita Vegetables, Lettuce]]
# 4621                    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Lettuce]]
#
#       item_price
# 0           2.39
# 1           3.39
# 2           3.39
# 3           2.39
# 4          16.98
# ...          ...
# 4617       11.75
# 4618       11.75
# 4619       11.25
# 4620        8.75
# 4621        8.75
#
# [4622 rows x 6 columns]

# %%
##3. What are the most popular 3 items?

orders_df.groupby('item_name').quantity.sum().sort_values(ascending = False).nlargest(3, keep='all')
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %%
##4. Which item has produced the most revenue?

orders_df.groupby('item_name').item_price.sum().nlargest(1,keep='all')
# Out:
# item_name
# Chicken Bowl    7342.73
# Name: item_price, dtype: float64

# %%
##5. Join the employees and titles DataFrames together.

get_db_url(username,password,host, 'employees')
emp_url = get_db_url(username,password,host, 'employees')
pd.read_sql('select * from employees limit 5', emp_url)
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
titles_df = pd.read_sql('select * from titles', emp_url)
titles_df
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
employees_df = pd.read_sql('select * from employees', emp_url)
employees_df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
employees_df.merge(titles_df,how='outer')
employees_titles_df = employees_df.merge(titles_df,how='outer')

employees_titles_df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# 2       Senior Engineer  1995-12-03  9999-01-01
# 3              Engineer  1986-12-01  1995-12-01
# 4       Senior Engineer  1995-12-01  9999-01-01
# ...                 ...         ...         ...
# 443303         Engineer  1987-08-30  1992-08-29
# 443304  Senior Engineer  1992-08-29  9999-01-01
# 443305     Senior Staff  1998-12-27  9999-01-01
# 443306            Staff  1993-12-27  1998-12-27
# 443307         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 9 columns]

# %%
##6. For each title, find the hire date of the employee that was hired most recently with that title.

employees_titles_df.groupby('title').hire_date.max()
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %%
##Write the code necessary to create a cross tabulation of the number of titles by department. 
##(Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)


titles_and_departments = '''
select * from employees
join dept_emp using(emp_no)
join titles using(emp_no)
join departments using(dept_no)
where dept_emp.to_date > curdate()
and titles.to_date > curdate()
'''
titles_and_departments_df = pd.read_sql(titles_and_departments,emp_url)
titles_and_departments_df.head(1)
pd.crosstab( titles_and_departments_df.dept_name, titles_and_departments_df.title)
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                    68       627        1             1790
# Development                       1652     14040        1            38816
# Finance                              0         0        1                0
# Human Resources                      0         0        1                0
# Marketing                            0         0        1                0
# Production                        1402     12081        1            33625
# Quality Management                 389      3405        1             9458
# Research                            77       830        1             2250
# Sales                                0         0        1                0
#
# title               Senior Staff  Staff  Technique Leader
# dept_name
# Customer Service           11268   3574               241
# Development                 1085    315              5477
# Finance                     9545   2891                 0
# Human Resources             9824   3073                 0
# Marketing                  11290   3551                 0
# Production                  1123    349              4723
# Quality Management             0      0              1293
# Research                    9092   2870               321
# Sales                      28797   8903                 0
